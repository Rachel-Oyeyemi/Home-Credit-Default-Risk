# %% [markdown]
# # 03 – Modeling
#
# In this notebook we train baseline and advanced models on the processed dataset and evaluate their performance.

# %%
from src.train_model import train_and_evaluate

results = train_and_evaluate()
results
