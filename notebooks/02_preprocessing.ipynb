# %% [markdown]
# # 02 – Preprocessing
#
# This notebook demonstrates how to preprocess the raw dataset using the project's preprocessing functions.

# %%
from pathlib import Path
import pandas as pd

from src.download_data import load_raw_data
from src.preprocess import preprocess_data, split_and_save

# Load raw data
df_raw = load_raw_data()

# Apply preprocessing
df_processed = preprocess_data(df_raw)

# Optionally split and save
train_df, test_df = split_and_save(df_processed)

train_df.head()
