# %% [markdown]
# # 04 – Business Insights
#
# This notebook summarises the key findings from the EDA and modelling, and outlines recommendations for the business.

# %% [markdown]
# - Higher income reduces default risk
# - Larger loan amounts and higher monthly payments increase default risk
# - Age and gender have little impact
# - Random Forest provides the best balance of precision and recall
#
# Refer to the `BUSINESS_RECOMMENDATIONS.md` file in the repository for a detailed discussion.
